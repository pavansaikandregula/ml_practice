# %% [markdown]
# # UNIVARIATE, BIVARIATE AND MULTIVARIATE ANALYSIS

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv('https://raw.githubusercontent.com/uiuc-cse/data-fa14/gh-pages/data/iris.csv')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.shape
# Out:
# (150, 5)

# %% [markdown]
# ### univariate analysis

# %%
df["species"] == "setosa"
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Name: species, Length: 150, dtype: bool

# %%
df_setosa = df.loc[df["species"] == "setosa"]

# %%
df_setosa
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# ...

# %%
df_virginica = df.loc[df['species'] == 'virginica']
df_viersicolor = df.loc[df['species'] == 'versicolor']

# %%
plt.plot(df_setosa['sepal_length'],np.zeros_like(df_setosa['sepal_length']),'o')
plt.plot(df_virginica['sepal_length'],np.zeros_like(df_virginica['sepal_length']),'o')
plt.plot(df_viersicolor['sepal_length'],np.zeros_like(df_viersicolor['sepal_length']),'o')
plt.show()

# %%
df_species
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# ...

# %% [markdown]
# Why do this?
#
# This is called a strip plot / rug-like visualization.
#
# You are doing univariate analysis.
#
# Since you're analyzing only one feature (sepal_length), there is no second variable for the y-axis.
#
# So the author places all observations at:
#
# y = 0
#
# and spreads them along the x-axis according to their sepal lengths.
#
# What your graph is showing
# Blue dots = Setosa sepal lengths
# Orange dots = Virginica sepal lengths
# Green dots = Versicolor sepal lengths
#
# All on the same horizontal line.
#
# 4.3  4.8  5.3  5.8  6.3  6.8  7.3  7.8
#
# ● ● ● ● ●          <- Setosa
#
#       ● ● ● ● ● ● ● ● ● ●   <- Versicolor
#
#                 ● ● ● ● ●   <- Virginica
#
# From this you can immediately see:
#
# Setosa generally has smaller sepal lengths.
# Virginica generally has larger sepal lengths.
# Versicolor is in between.

# %% [markdown]
# #### bivariate analysis

# %%
sns.FacetGrid(df,hue = "species").map(plt.scatter,"petal_length","sepal_width").add_legend();

# %% [markdown]
# ### multivariate analysis

# %%
sns.pairplot(df,hue = "species",height = 5)
